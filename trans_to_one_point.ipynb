# %%
# %run C://Users/a/apython/__init__/Normal_for_DSS.py
import cv2

# %%
from PIL import Image, ImageFilter
from skimage import io
import os
file = os.path.join('C:/Users/a/GitHub/make_algorithm_diagram/datas/num.jpg')
num = io.imread(file)

# %%
num = Image.open('C:/Users/a/GitHub/make_algorithm_diagram/datas/num.jpg').convert('L')
num_np = np.array(num)
num_ = 256 - num_np
num_a =  num_/256.
num_b = np.log(cv2.GaussianBlur(num_a,(5,5),0))
num_bb = cv2.GaussianBlur(num_a,(5,5),0)
plt.imshow(num_b)
plt.show()

# %%
num_c = num_b
for i in range (1, len(num_a[0])-1):
    for j in range(1, len(num_a)-1):
        if num_b[j,i] > 0.03 :
             if num_b[j-1:j+2,i-1:i+2].sum() >= 2:
                    num_c[j][i] = 0

plt.figure(figsize=(100,100))
plt.imshow(num_b)
plt.show()

# %%
404*450
# Out:
# 181800

# %%
k = num_a > 0.5
for i in range (len(num_a[0])):
    for j in range(len(num_a)):
        if k[j,i] == False:
            k[j,i] = 0
        else : 
            k[j,i] = 1 
k
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
len(num_a[0])
# Out:
# 450

# %%
num_a[3:5, 3:5]
# Out:
# array([[ 0.00390625,  0.00390625],
#        [ 0.00390625,  0.00390625]])
