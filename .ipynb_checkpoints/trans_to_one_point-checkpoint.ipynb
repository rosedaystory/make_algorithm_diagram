# %%
# %run C://Users/a/apython/__init__/Normal_for_DSS.py
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %%
from PIL import Image, ImageFilter
from skimage import io
import os
file = os.path.join('C:/Users/a/GitHub/make_algorithm_diagram/datas/num.jpg')
num = io.imread(file)

# %%
num = Image.open('C:/Users/a/GitHub/make_algorithm_diagram/datas/num.jpg').convert('L')
num_np = np.array(num)
num_ = 256 - num_np
num_a =  num_/256.
plt.imshow(num__)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-bbc243bc20fc> in <module>()
#       3 num_ = 256 - num_np
#       4 num_a =  num_/256.
# ----> 5 plt.imshow(num__)
#       6 plt.show()
#       7 num__ = num_a.fill
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
num_b = num_a
for i in range (1, len(num_a[0])-1):
    for j in range(1, len(num_a)-1):
        if num_a[j,i] > 0.3 :
             if num_a[j-1:j+2,i-1:i+2].sum() >= 2:
                    num_b[j][i] = 0

plt.figure(figsize=(100,100))
plt.imshow(num_b)
plt.show()

# %%
404*450
# Out:
# 181800

# %%
k = num_a > 0.5
for i in range (len(num_a[0])):
    for j in range(len(num_a)):
        if k[j,i] == False:
            k[j,i] = 0
        else : 
            k[j,i] = 1 
k
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
len(num_a[0])
# Out:
# 450

# %%
num_a[3:5, 3:5]
# Out:
# array([[ 0.00390625,  0.00390625],
#        [ 0.00390625,  0.00390625]])
