# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("C://Users/a/GitHub/make_algorithm_diagram/datas/num.jpg",-1)
plt.imshow(img)
plt.show()

# %%
cv2.rectangle(img, (50,50), (200, 250),(0,255,0),3)
plt.imshow(img)
plt.show()

# %%
cv2.circle(img, (100,100),50, (0,0,255),3)
plt.imshow(img)
plt.show()
